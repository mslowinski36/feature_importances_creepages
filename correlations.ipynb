# %%
import pandas as pd 
import scipy.stats 
import os 
import numpy as np
from seaborn import heatmap
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('dataset.csv')
df
# Out:
#         time  velocity  long_creepage  yaw_angle  wear_number  \
# 0      19.81   5.55108       0.000667  -0.009065    23.452800
# 1       1.99   5.26723      -0.001248   0.000031     0.020740
# 2      24.36   5.54751      -0.000984  -0.002053     0.293188
# 3      61.30   5.55212       0.016841   0.007345   152.713000
# 4      28.32   5.54444       0.000080  -0.006540     0.266178
# ...      ...       ...            ...        ...          ...
# 19473  19.70   8.31473       0.000164   0.001777    20.652100
# 19474  47.57   5.56795      -0.008443   0.037504   202.171000
# 19475  20.70  13.88650      -0.005157   0.005796   173.089000
# 19476  42.40  13.90070      -0.001037   0.009230     8.488080
# 19477  85.30   5.54712       0.000948  -0.003834     1.081580
#
#        lateral_displacement  lateral_creepage  spin_creepage  yaw_angle_pos  \
# 0                  0.003855          0.000725       0.762058       0.001303
# ...

# %%
df.corr()

fig,ax = plt.subplots(figsize=(8,8))
ax = heatmap(df.corr(method='spearman'), fmt=".2f",annot=True,ax=ax,cmap='RdBu_r',vmax=1,vmin=-1)
